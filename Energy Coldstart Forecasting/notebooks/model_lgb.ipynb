# %%
# %matplotlib inline

# plotting
import matplotlib as mpl
mpl.style.use('ggplot')
import matplotlib.pyplot as plt

# math and data manipulation
import numpy as np
import pandas as pd

# set random seeds 
from numpy.random import seed
from dateutil.parser import parse
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, LabelBinarizer, LabelEncoder, Normalizer, StandardScaler
from sklearn.metrics import *
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.externals import joblib
# modeling
import lightgbm as lgb
import xgboost as xgb
# progress bar
from tqdm import tqdm
import gc

# %%
train = pd.read_csv('../data/consumption_train.csv',parse_dates=['timestamp'],index_col=0)
train.head(5)
# Out:
#    series_id           timestamp    consumption  temperature
# 0     103088 2014-12-24 00:00:00  101842.233424          NaN
# 1     103088 2014-12-24 01:00:00  105878.048906          NaN
# 2     103088 2014-12-24 02:00:00   91619.105008          NaN
# 3     103088 2014-12-24 03:00:00   94473.706203          NaN
# 4     103088 2014-12-24 04:00:00   96976.755526          NaN

# %%
print (train.shape)
print (train.series_id.nunique())
# Out:
# (509376, 4)
# 758

# %%
test = pd.read_csv('../data/cold_start_test.csv',index_col=0,parse_dates=['timestamp'])
test.head(5)
# Out:
#    series_id           timestamp   consumption  temperature
# 0     102781 2013-02-27 00:00:00  15295.740389        17.00
# 1     102781 2013-02-27 01:00:00  15163.209562        18.25
# 2     102781 2013-02-27 02:00:00  15022.264079        18.00
# 3     102781 2013-02-27 03:00:00  15370.420458        17.00
# 4     102781 2013-02-27 04:00:00  15303.103213        16.90

# %%
my_submission = pd.read_csv('../data/submission_format.csv')
my_submission.head(3)
# Out:
#    pred_id  series_id            timestamp  temperature  consumption  \
# 0        0     102781  2013-03-03 00:00:00    19.931250          0.0
# 1        1     102781  2013-03-04 00:00:00    20.034375          0.0
# 2        2     102781  2013-03-05 00:00:00    19.189583          0.0
#
#   prediction_window
# 0             daily
# 1             daily
# 2             daily

# %%
meta = pd.read_csv('../data/meta.csv')
meta.head(5)
# Out:
#    series_id  surface base_temperature  monday_is_day_off  tuesday_is_day_off  \
# 0     100003  x-large              low              False               False
# 1     100004  x-large              low              False               False
# 2     100006  x-small              low              False               False
# 3     100008  x-small              low              False               False
# 4     100010  x-small              low              False               False
#
#    wednesday_is_day_off  thursday_is_day_off  friday_is_day_off  \
# 0                 False                False              False
# 1                 False                False              False
# 2                 False                False              False
# 3                 False                False              False
# 4                 False                False              False
#
#    saturday_is_day_off  sunday_is_day_off
# 0                 True               True
# 1                 True               True
# 2                 True               True
# 3                 True               True
# 4                 True               True

# %%
for col in meta.columns:
    if col != 'series_id':
        clf = LabelEncoder()
        meta[col] = clf.fit_transform(meta[col])

# %%
meta.head(5)
# Out:
#    series_id  surface  base_temperature  monday_is_day_off  \
# 0     100003        3                 1                  0
# 1     100004        3                 1                  0
# 2     100006        4                 1                  0
# 3     100008        4                 1                  0
# 4     100010        4                 1                  0
#
#    tuesday_is_day_off  wednesday_is_day_off  thursday_is_day_off  \
# 0                   0                     0                    0
# 1                   0                     0                    0
# 2                   0                     0                    0
# 3                   0                     0                    0
# 4                   0                     0                    0
#
#    friday_is_day_off  saturday_is_day_off  sunday_is_day_off
# 0                  0                    1                  1
# 1                  0                    1                  1
# 2                  0                    1                  1
# 3                  0                    1                  1
# 4                  0                    1                  1

# %%
train = pd.merge(train,meta,how="left")
test = pd.merge(test,meta,how="left")
my_submission = pd.merge(my_submission,meta,how="left")

# %%
def create_lagged_features(df, lag=1):
    if not type(df) == pd.DataFrame:
        df = pd.DataFrame(df, columns=['consumption'])
    
    def _rename_lag(ser, j):
        ser.name = ser.name + f'_{j}'
        return ser
        
    # add a column lagged by `i` steps
    if len(df) > lag:
        for i in range(1, lag + 1):
            df = df.join(df.consumption.shift(i).pipe(_rename_lag, i))
    else:
        for i in range(1, lag):
            df = df.join(df.consumption.shift(i).pipe(_rename_lag, i))
        df.columns = ['consumption_'+str(i) for i in range(1,lag+1)]

    df.dropna(inplace=True)
    return df

# %%
days = {0:'monday',1:'tuesday',2:'wednesday',3:'thursday',4:'friday',5:'saturday',6:'sunday'}
daysnum = {'monday':1,'tuesday':2,'wednesday':3,'thursday':4,'friday':5,'saturday':6,'sunday':7}

# %%
def prepare_training_data(df, lag):
    """ Converts a series of consumption data into a
        lagged, scaled sample.
    """
    consumption_series = df.consumption
    # scale training data
    scaler = MinMaxScaler(feature_range=(0, 1))
    consumption_vals = scaler.fit_transform(consumption_series.values.reshape(-1, 1))
    
    # convert consumption series to lagged features
    consumption_lagged = create_lagged_features(consumption_vals, lag=lag)
    
    consumption_lagged['series_id'] = df.series_id.iloc[0]
    consumption_lagged['surface'] = df.surface.iloc[0]
    consumption_lagged['base_temp'] = df.base_temperature.iloc[0]
    
    consumption_lagged['day_of_week'] = [days[(df.timestamp.iloc[i+lag-1].dayofweek+1)%7] for i in range(0,len(consumption_lagged))]
    consumption_lagged['is_off'] = consumption_lagged.day_of_week.apply(lambda x: df[x+'_is_day_off'].iloc[0])
    
    consumption_lagged['day_of_week'] = consumption_lagged.day_of_week.apply(lambda x: daysnum[x])
    # X, y format taking the first column (original time series) to be the y
    if len(consumption_series) > lag:
        X = consumption_lagged.drop('consumption', axis=1)
        y = list(consumption_lagged.consumption.values)
    elif len(consumption_series) == lag:
        X = consumption_lagged
        y = []
        
    return X, y, scaler

# %%
lag = 72

# %%
X24 = pd.DataFrame()
y24 = []
for ser_id, ser_data in tqdm(train.groupby('series_id')):

    # prepare the data
    X, y, scaler = prepare_training_data(ser_data, lag)
    X24 = pd.concat([X24,X],axis=0)
    y24 += y
# Out:
#   0%|          | 0/758 [00:00<?, ?it/s]
#   0%|          | 1/758 [00:02<25:42,  2.04s/it]
#   0%|          | 2/758 [00:02<17:08,  1.36s/it]
#   0%|          | 3/758 [00:03<14:01,  1.11s/it]
#   1%|          | 4/758 [00:03<12:21,  1.02it/s]
#   1%|          | 5/758 [00:04<11:35,  1.08it/s]
#   1%|          | 6/758 [00:05<10:56,  1.15it/s]
#   1%|          | 7/758 [00:05<10:29,  1.19it/s]
#   1%|          | 8/758 [00:06<10:12,  1.22it/s]
#   1%|          | 9/758 [00:07<09:59,  1.25it/s]
#   1%|▏         | 10/758 [00:07<09:57,  1.25it/s]Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/home/victor/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/victor/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 148, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/victor/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 100%|██████████| 758/758 [09:46<00:00,  1.29it/s]

# %%
from numba import jit
import math

@jit
def smape_fast(y_true, y_pred):
    out = 0
    for i in range(y_true.shape[0]):
        a = y_true[i]
        b = y_pred[i]
        #if b < 1:
        #    b = 0
        c = a
        if c == 0:
            continue
        out += math.fabs(a - b) / c
    out *= (100.0 / y_true.shape[0])
    return out

def lgb_smape(preds, df):
    labels = df.get_label()
    labels, preds = np.array(labels), np.array(preds) #np.expm1(np.array(labels)), np.expm1(np.array(preds))
    return 'mape', smape_fast(labels, preds), False

def mape(y_true,y_pred):
    l = []
    for i in range(len(y_true)):
        if y_true[i] != 0:
            l.append(np.abs(y_true[i]-y_pred[i])/y_true[i]*100)
    return np.mean(l)

# %%
train_cols = list(X24.columns)
train_cols.remove('series_id')
X24['target'] = y24

# %%
group_kfold = GroupKFold(n_splits=5)
for train_index, val_index in group_kfold.split(X24, y24, X24.series_id):
    pass

# %%
lgb_train = lgb.Dataset(X24[train_cols].iloc[train_index], label=X24['target'].iloc[train_index], free_raw_data=False)
lgb_val = lgb.Dataset(X24[train_cols].iloc[val_index], label=X24['target'].iloc[val_index], free_raw_data=False, reference=lgb_train)

# %%
param = {}
param['application'] = 'regression_l2'
param['learning_rate'] = 0.05

# %%
model = lgb.train(param, lgb_train, 1000, valid_sets=[lgb_train,lgb_val],early_stopping_rounds=50,feval=lgb_smape)
# Out:
# [1]	training's mape: 1268.83	valid_1's mape: 1575.6
# Train until valid scores didn't improve in 50 rounds.
# [2]	training's mape: 1213.79	valid_1's mape: 1505.5
# [3]	training's mape: 1161.34	valid_1's mape: 1438.65
# [4]	training's mape: 1111.75	valid_1's mape: 1375.73
# [5]	training's mape: 1063.54	valid_1's mape: 1314.84
# [6]	training's mape: 1018.84	valid_1's mape: 1258.12
# [7]	training's mape: 977.536	valid_1's mape: 1205.39
# [8]	training's mape: 936.814	valid_1's mape: 1153.98
# [9]	training's mape: 898.387	valid_1's mape: 1105.52
# [10]	training's mape: 861.781	valid_1's mape: 1057.92
# [11]	training's mape: 826.724	valid_1's mape: 1013.62
# [12]	training's mape: 794.076	valid_1's mape: 972.19
# [13]	training's mape: 761.946	valid_1's mape: 932.119
# [14]	training's mape: 732.208	valid_1's mape: 894.694
# [15]	training's mape: 703.001	valid_1's mape: 858.046
# [16]	training's mape: 676.314	valid_1's mape: 823.633
# [17]	training's mape: 649.573	valid_1's mape: 790.637
# [18]	training's mape: 625.683	valid_1's mape: 759.577
# [19]	training's mape: 601.583	valid_1's mape: 729.498
# [20]	training's mape: 579.623	valid_1's mape: 701.111
# [21]	training's mape: 557.837	valid_1's mape: 674.178
# [22]	training's mape: 537.33	valid_1's mape: 647.735
# [23]	training's mape: 517.241	valid_1's mape: 622.641
# [24]	training's mape: 499.908	valid_1's mape: 599.89
# [25]	training's mape: 481.737	valid_1's mape: 577.406
# [26]	training's mape: 464.927	valid_1's mape: 556.268
# [27]	training's mape: 449.458	valid_1's mape: 537.246
# [28]	training's mape: 433.686	valid_1's mape: 517.738
# [29]	training's mape: 419.869	valid_1's mape: 499.76
# [30]	training's mape: 406.903	valid_1's mape: 483.909
# [31]	training's mape: 393.619	valid_1's mape: 467.255
# [32]	training's mape: 381.198	valid_1's mape: 451.957
# [33]	training's mape: 368.605	valid_1's mape: 436.318
# [34]	training's mape: 357.567	valid_1's mape: 422.476
# [35]	training's mape: 346.338	valid_1's mape: 408.138
# [36]	training's mape: 335.516	valid_1's mape: 394.488
# [37]	training's mape: 326.281	valid_1's mape: 382.6
# [38]	training's mape: 316.931	valid_1's mape: 370.965
# [39]	training's mape: 308.857	valid_1's mape: 360.181
# [40]	training's mape: 300.094	valid_1's mape: 349.331
# [41]	training's mape: 292.296	valid_1's mape: 339.652
# [42]	training's mape: 284.385	valid_1's mape: 329.864
# [43]	training's mape: 276.981	valid_1's mape: 320.521
# [44]	training's mape: 269.382	valid_1's mape: 311.094
# [45]	training's mape: 262.733	valid_1's mape: 302.708
# [46]	training's mape: 255.624	valid_1's mape: 293.342
# [47]	training's mape: 249.692	valid_1's mape: 285.864
# [48]	training's mape: 243.312	valid_1's mape: 277.936
# [49]	training's mape: 237.686	valid_1's mape: 271.231
# [50]	training's mape: 232.895	valid_1's mape: 265.086
# [51]	training's mape: 227.748	valid_1's mape: 258.63
# [52]	training's mape: 222.831	valid_1's mape: 252.34
# [53]	training's mape: 218.294	valid_1's mape: 246.64
# [54]	training's mape: 213.612	valid_1's mape: 240.412
# [55]	training's mape: 208.709	valid_1's mape: 234.218
# [56]	training's mape: 204.397	valid_1's mape: 229.128
# [57]	training's mape: 200.329	valid_1's mape: 223.712
# [58]	training's mape: 196.391	valid_1's mape: 218.699
# [59]	training's mape: 193.028	valid_1's mape: 214.573
# [60]	training's mape: 189.904	valid_1's mape: 210.72
# [61]	training's mape: 186.864	valid_1's mape: 207.005
# [62]	training's mape: 183.127	valid_1's mape: 202.327
# [63]	training's mape: 179.834	valid_1's mape: 198.166
# [64]	training's mape: 177.248	valid_1's mape: 194.789
# [65]	training's mape: 174.263	valid_1's mape: 191.003
# [66]	training's mape: 171.888	valid_1's mape: 188.187
# [67]	training's mape: 169.481	valid_1's mape: 185.342
# [68]	training's mape: 167.419	valid_1's mape: 182.711
# [69]	training's mape: 165.429	valid_1's mape: 180.478
# [70]	training's mape: 163.006	valid_1's mape: 177.904
# [71]	training's mape: 161.222	valid_1's mape: 175.71
# [72]	training's mape: 159.188	valid_1's mape: 172.86
# [73]	training's mape: 157.316	valid_1's mape: 170.522
# [74]	training's mape: 155.581	valid_1's mape: 168.45
# [75]	training's mape: 153.466	valid_1's mape: 165.879
# [76]	training's mape: 151.762	valid_1's mape: 163.76
# [77]	training's mape: 149.615	valid_1's mape: 160.949
# [78]	training's mape: 148.076	valid_1's mape: 158.929
# [79]	training's mape: 146.304	valid_1's mape: 156.687
# [80]	training's mape: 144.832	valid_1's mape: 154.794
# [81]	training's mape: 143.814	valid_1's mape: 153.546
# [82]	training's mape: 142.934	valid_1's mape: 152.479
# [83]	training's mape: 141.929	valid_1's mape: 151.313
# [84]	training's mape: 140.008	valid_1's mape: 148.785
# [85]	training's mape: 139.138	valid_1's mape: 147.654
# [86]	training's mape: 138.111	valid_1's mape: 146.139
# [87]	training's mape: 136.75	valid_1's mape: 144.799
# [88]	training's mape: 135.283	valid_1's mape: 142.918
# [89]	training's mape: 134.5	valid_1's mape: 141.93
# [90]	training's mape: 133.132	valid_1's mape: 140.094
# [91]	training's mape: 131.675	valid_1's mape: 138.2
# [92]	training's mape: 130.861	valid_1's mape: 137.135
# [93]	training's mape: 130.082	valid_1's mape: 136.161
# [94]	training's mape: 129.374	valid_1's mape: 135.444
# [95]	training's mape: 128.813	valid_1's mape: 134.59
# [96]	training's mape: 128.385	valid_1's mape: 134.115
# [97]	training's mape: 127.87	valid_1's mape: 133.499
# [98]	training's mape: 127.184	valid_1's mape: 132.693
# [99]	training's mape: 126.681	valid_1's mape: 132.121
# [100]	training's mape: 126.157	valid_1's mape: 131.519
# [101]	training's mape: 125.702	valid_1's mape: 130.973
# [102]	training's mape: 125.18	valid_1's mape: 130.394
# [103]	training's mape: 123.998	valid_1's mape: 128.871
# [104]	training's mape: 122.959	valid_1's mape: 127.346
# [105]	training's mape: 122.678	valid_1's mape: 126.894
# [106]	training's mape: 121.749	valid_1's mape: 125.691
# [107]	training's mape: 121.229	valid_1's mape: 125.084
# [108]	training's mape: 120.904	valid_1's mape: 124.712
# [109]	training's mape: 120.457	valid_1's mape: 124.216
# [110]	training's mape: 119.632	valid_1's mape: 123.028
# [111]	training's mape: 118.627	valid_1's mape: 121.838
# [112]	training's mape: 118.173	valid_1's mape: 121.146
# [113]	training's mape: 117.448	valid_1's mape: 120.191
# [114]	training's mape: 117.128	valid_1's mape: 119.904
# [115]	training's mape: 116.753	valid_1's mape: 119.399
# [116]	training's mape: 116.529	valid_1's mape: 119.188
# [117]	training's mape: 116.085	valid_1's mape: 118.845
# [118]	training's mape: 115.588	valid_1's mape: 118.111
# [119]	training's mape: 114.881	valid_1's mape: 117.063
# [120]	training's mape: 114.234	valid_1's mape: 116.709
# [121]	training's mape: 114.053	valid_1's mape: 116.472
# [122]	training's mape: 113.84	valid_1's mape: 116.3
# [123]	training's mape: 113.658	valid_1's mape: 115.975
# [124]	training's mape: 113.497	valid_1's mape: 115.654
# [125]	training's mape: 113.285	valid_1's mape: 115.38
# [126]	training's mape: 113.26	valid_1's mape: 115.333
# [127]	training's mape: 112.526	valid_1's mape: 114.361
# [128]	training's mape: 112.556	valid_1's mape: 114.308
# [129]	training's mape: 112.416	valid_1's mape: 114.208
# [130]	training's mape: 111.777	valid_1's mape: 113.31
# [131]	training's mape: 111.823	valid_1's mape: 113.431
# [132]	training's mape: 111.839	valid_1's mape: 113.437
# [133]	training's mape: 111.591	valid_1's mape: 113.183
# [134]	training's mape: 110.943	valid_1's mape: 112.638
# [135]	training's mape: 110.812	valid_1's mape: 112.637
# [136]	training's mape: 110.796	valid_1's mape: 112.657
# [137]	training's mape: 110.364	valid_1's mape: 112.219
# [138]	training's mape: 110.28	valid_1's mape: 112.125
# [139]	training's mape: 110.107	valid_1's mape: 111.869
# [140]	training's mape: 109.571	valid_1's mape: 111.128
# [141]	training's mape: 109.65	valid_1's mape: 111.186
# [142]	training's mape: 109.177	valid_1's mape: 110.514
# [143]	training's mape: 108.896	valid_1's mape: 110.311
# [144]	training's mape: 108.765	valid_1's mape: 110.091
# [145]	training's mape: 108.385	valid_1's mape: 109.859
# [146]	training's mape: 108.07	valid_1's mape: 109.136
# [147]	training's mape: 108.04	valid_1's mape: 109.096
# [148]	training's mape: 107.907	valid_1's mape: 108.92
# [149]	training's mape: 107.818	valid_1's mape: 108.866
# [150]	training's mape: 107.797	valid_1's mape: 108.875
# [151]	training's mape: 107.25	valid_1's mape: 108.122
# [152]	training's mape: 107.275	valid_1's mape: 108.145
# [153]	training's mape: 107.266	valid_1's mape: 108.132
# [154]	training's mape: 107.193	valid_1's mape: 108.043
# [155]	training's mape: 106.798	valid_1's mape: 107.603
# [156]	training's mape: 106.752	valid_1's mape: 107.548
# [157]	training's mape: 106.551	valid_1's mape: 107.38
# [158]	training's mape: 106.141	valid_1's mape: 107.127
# [159]	training's mape: 105.89	valid_1's mape: 106.909
# [160]	training's mape: 105.933	valid_1's mape: 106.959
# [161]	training's mape: 105.541	valid_1's mape: 106.501
# [162]	training's mape: 105.47	valid_1's mape: 106.427
# [163]	training's mape: 105.357	valid_1's mape: 106.298
# [164]	training's mape: 105.399	valid_1's mape: 106.287
# [165]	training's mape: 105.18	valid_1's mape: 106.081
# [166]	training's mape: 105.146	valid_1's mape: 106.062
# [167]	training's mape: 104.827	valid_1's mape: 105.72
# [168]	training's mape: 104.767	valid_1's mape: 105.649
# [169]	training's mape: 104.555	valid_1's mape: 105.639
# [170]	training's mape: 104.535	valid_1's mape: 105.648
# [171]	training's mape: 103.867	valid_1's mape: 105.046
# [172]	training's mape: 103.742	valid_1's mape: 104.936
# [173]	training's mape: 103.739	valid_1's mape: 104.894
# [174]	training's mape: 103.744	valid_1's mape: 104.913
# [175]	training's mape: 103.741	valid_1's mape: 104.906
# [176]	training's mape: 103.369	valid_1's mape: 104.459
# [177]	training's mape: 103.286	valid_1's mape: 104.418
# [178]	training's mape: 103.236	valid_1's mape: 104.443
# [179]	training's mape: 103.224	valid_1's mape: 104.351
# [180]	training's mape: 103.037	valid_1's mape: 104.158
# [181]	training's mape: 102.969	valid_1's mape: 104.052
# [182]	training's mape: 102.961	valid_1's mape: 104.034
# [183]	training's mape: 102.957	valid_1's mape: 103.971
# [184]	training's mape: 102.42	valid_1's mape: 103.406
# [185]	training's mape: 102.413	valid_1's mape: 103.385
# [186]	training's mape: 102.355	valid_1's mape: 103.338
# [187]	training's mape: 102.367	valid_1's mape: 103.375
# [188]	training's mape: 101.724	valid_1's mape: 102.812
# [189]	training's mape: 101.655	valid_1's mape: 102.691
# [190]	training's mape: 101.595	valid_1's mape: 102.591
# [191]	training's mape: 101.491	valid_1's mape: 102.434
# [192]	training's mape: 101.485	valid_1's mape: 102.418
# [193]	training's mape: 101.388	valid_1's mape: 102.297
# [194]	training's mape: 101.275	valid_1's mape: 102.295
# [195]	training's mape: 101.181	valid_1's mape: 102.105
# [196]	training's mape: 100.95	valid_1's mape: 101.84
# [197]	training's mape: 100.805	valid_1's mape: 101.759
# [198]	training's mape: 100.504	valid_1's mape: 101.501
# [199]	training's mape: 100.517	valid_1's mape: 101.461
# [200]	training's mape: 100.387	valid_1's mape: 101.426
# [201]	training's mape: 100.373	valid_1's mape: 101.403
# [202]	training's mape: 100.348	valid_1's mape: 101.374
# [203]	training's mape: 100.33	valid_1's mape: 101.369
# [204]	training's mape: 100.301	valid_1's mape: 101.354
# [205]	training's mape: 100.179	valid_1's mape: 101.01
# [206]	training's mape: 99.9407	valid_1's mape: 100.836
# [207]	training's mape: 99.9171	valid_1's mape: 100.769
# [208]	training's mape: 99.8721	valid_1's mape: 100.712
# [209]	training's mape: 99.7838	valid_1's mape: 100.48
# [210]	training's mape: 99.1998	valid_1's mape: 100.174
# [211]	training's mape: 99.0745	valid_1's mape: 99.9212
# [212]	training's mape: 98.9338	valid_1's mape: 99.9065
# [213]	training's mape: 98.9544	valid_1's mape: 100.014
# [214]	training's mape: 98.9067	valid_1's mape: 100.011
# [215]	training's mape: 98.7602	valid_1's mape: 99.97
# [216]	training's mape: 98.802	valid_1's mape: 99.9827
# [217]	training's mape: 98.7896	valid_1's mape: 99.9734
# [218]	training's mape: 98.7298	valid_1's mape: 99.8582
# [219]	training's mape: 98.6883	valid_1's mape: 99.8288
# [220]	training's mape: 98.6703	valid_1's mape: 99.825
# [221]	training's mape: 98.7349	valid_1's mape: 99.9023
# [222]	training's mape: 98.5278	valid_1's mape: 99.6281
# [223]	training's mape: 98.4975	valid_1's mape: 99.6194
# [224]	training's mape: 98.5668	valid_1's mape: 100.07
# [225]	training's mape: 98.5538	valid_1's mape: 100.024
# [226]	training's mape: 98.4656	valid_1's mape: 99.7804
# [227]	training's mape: 98.4337	valid_1's mape: 99.7259
# [228]	training's mape: 98.417	valid_1's mape: 99.7159
# [229]	training's mape: 98.4692	valid_1's mape: 99.7956
# [230]	training's mape: 98.4218	valid_1's mape: 99.677
# [231]	training's mape: 98.4533	valid_1's mape: 99.7559
# [232]	training's mape: 98.2251	valid_1's mape: 99.6598
# [233]	training's mape: 98.196	valid_1's mape: 99.6229
# [234]	training's mape: 98.255	valid_1's mape: 99.857
# [235]	training's mape: 98.2012	valid_1's mape: 99.7122
# [236]	training's mape: 98.1475	valid_1's mape: 99.6881
# [237]	training's mape: 98.1176	valid_1's mape: 99.6748
# [238]	training's mape: 97.7319	valid_1's mape: 99.4217
# [239]	training's mape: 97.6975	valid_1's mape: 99.3928
# [240]	training's mape: 97.7075	valid_1's mape: 99.4688
# [241]	training's mape: 97.5176	valid_1's mape: 99.2849
# [242]	training's mape: 97.4833	valid_1's mape: 99.274
# [243]	training's mape: 97.4686	valid_1's mape: 99.2519
# [244]	training's mape: 97.3851	valid_1's mape: 99.1646
# [245]	training's mape: 97.3272	valid_1's mape: 99.1545
# [246]	training's mape: 97.2414	valid_1's mape: 99.0352
# [247]	training's mape: 97.1627	valid_1's mape: 98.8992
# [248]	training's mape: 96.7973	valid_1's mape: 98.5694
# [249]	training's mape: 96.7451	valid_1's mape: 98.537
# [250]	training's mape: 96.5756	valid_1's mape: 98.4649
# [251]	training's mape: 96.5593	valid_1's mape: 98.4633
# [252]	training's mape: 96.5553	valid_1's mape: 98.4683
# [253]	training's mape: 96.4888	valid_1's mape: 98.4713
# [254]	training's mape: 96.3894	valid_1's mape: 98.3737
# [255]	training's mape: 96.3101	valid_1's mape: 98.3172
# [256]	training's mape: 96.2353	valid_1's mape: 98.3105
# [257]	training's mape: 96.1893	valid_1's mape: 97.971
# [258]	training's mape: 96.0882	valid_1's mape: 97.857
# [259]	training's mape: 95.966	valid_1's mape: 97.812
# [260]	training's mape: 95.9492	valid_1's mape: 97.8638
# [261]	training's mape: 95.9358	valid_1's mape: 97.8558
# [262]	training's mape: 95.4552	valid_1's mape: 97.5461
# [263]	training's mape: 95.4277	valid_1's mape: 97.539
# [264]	training's mape: 95.418	valid_1's mape: 97.5751
# [265]	training's mape: 95.2543	valid_1's mape: 97.4964
# [266]	training's mape: 95.2387	valid_1's mape: 97.4813
# [267]	training's mape: 95.2164	valid_1's mape: 97.4813
# [268]	training's mape: 95.1582	valid_1's mape: 97.4042
# [269]	training's mape: 95.1534	valid_1's mape: 97.4243
# [270]	training's mape: 95.1069	valid_1's mape: 97.3512
# [271]	training's mape: 95.0224	valid_1's mape: 97.2715
# [272]	training's mape: 94.7438	valid_1's mape: 97.0794
# [273]	training's mape: 94.7883	valid_1's mape: 97.1209
# [274]	training's mape: 94.7911	valid_1's mape: 97.152
# [275]	training's mape: 94.7399	valid_1's mape: 97.1594
# [276]	training's mape: 94.7379	valid_1's mape: 97.1673
# [277]	training's mape: 94.7117	valid_1's mape: 97.1479
# [278]	training's mape: 94.7109	valid_1's mape: 97.0938
# [279]	training's mape: 94.666	valid_1's mape: 97.0264
# [280]	training's mape: 94.5529	valid_1's mape: 96.8231
# [281]	training's mape: 94.603	valid_1's mape: 96.8832
# [282]	training's mape: 94.4654	valid_1's mape: 96.7347
# [283]	training's mape: 94.3847	valid_1's mape: 96.6272
# [284]	training's mape: 94.2428	valid_1's mape: 96.4383
# [285]	training's mape: 94.1943	valid_1's mape: 96.26
# [286]	training's mape: 94.1783	valid_1's mape: 96.3461
# [287]	training's mape: 94.1452	valid_1's mape: 96.3373
# [288]	training's mape: 93.6685	valid_1's mape: 95.9471
# [289]	training's mape: 93.7401	valid_1's mape: 95.93
# [290]	training's mape: 93.6955	valid_1's mape: 95.8562
# [291]	training's mape: 93.6477	valid_1's mape: 95.8207
# [292]	training's mape: 93.6802	valid_1's mape: 95.9045
# [293]	training's mape: 93.6497	valid_1's mape: 95.8733
# [294]	training's mape: 93.6645	valid_1's mape: 95.9087
# [295]	training's mape: 93.6914	valid_1's mape: 95.9229
# [296]	training's mape: 93.3195	valid_1's mape: 95.5516
# [297]	training's mape: 93.2142	valid_1's mape: 95.4626
# [298]	training's mape: 92.9678	valid_1's mape: 95.3858
# [299]	training's mape: 92.956	valid_1's mape: 95.3756
# [300]	training's mape: 92.9508	valid_1's mape: 95.3783
# [301]	training's mape: 92.958	valid_1's mape: 95.3817
# [302]	training's mape: 92.8692	valid_1's mape: 95.221
# [303]	training's mape: 92.8731	valid_1's mape: 95.2593
# [304]	training's mape: 92.7647	valid_1's mape: 95.1037
# [305]	training's mape: 92.7392	valid_1's mape: 95.0849
# [306]	training's mape: 92.6617	valid_1's mape: 95.0439
# [307]	training's mape: 92.3664	valid_1's mape: 94.6996
# [308]	training's mape: 92.3521	valid_1's mape: 94.7409
# [309]	training's mape: 92.2459	valid_1's mape: 94.598
# [310]	training's mape: 92.234	valid_1's mape: 94.6066
# [311]	training's mape: 92.2817	valid_1's mape: 94.6393
# [312]	training's mape: 92.2146	valid_1's mape: 94.5813
# [313]	training's mape: 92.2451	valid_1's mape: 94.625
# [314]	training's mape: 92.2802	valid_1's mape: 94.653
# [315]	training's mape: 92.2206	valid_1's mape: 94.5589
# [316]	training's mape: 92.2207	valid_1's mape: 94.6012
# [317]	training's mape: 92.215	valid_1's mape: 94.6187
# [318]	training's mape: 92.1859	valid_1's mape: 94.6042
# [319]	training's mape: 92.1388	valid_1's mape: 94.4153
# [320]	training's mape: 92.1031	valid_1's mape: 94.4558
# [321]	training's mape: 92.092	valid_1's mape: 94.4406
# [322]	training's mape: 92.0351	valid_1's mape: 94.4117
# [323]	training's mape: 91.9962	valid_1's mape: 94.3835
# [324]	training's mape: 91.975	valid_1's mape: 94.374
# [325]	training's mape: 91.8328	valid_1's mape: 94.4041
# [326]	training's mape: 91.7412	valid_1's mape: 94.4418
# [327]	training's mape: 91.6724	valid_1's mape: 94.4638
# [328]	training's mape: 91.6798	valid_1's mape: 94.4538
# [329]	training's mape: 91.7137	valid_1's mape: 94.4805
# [330]	training's mape: 91.5846	valid_1's mape: 94.4478
# [331]	training's mape: 91.5475	valid_1's mape: 94.3428
# [332]	training's mape: 91.4682	valid_1's mape: 94.2198
# [333]	training's mape: 91.4645	valid_1's mape: 94.2221
# [334]	training's mape: 91.4183	valid_1's mape: 94.1999
# [335]	training's mape: 91.4567	valid_1's mape: 94.2685
# [336]	training's mape: 91.4467	valid_1's mape: 94.2576
# [337]	training's mape: 91.4012	valid_1's mape: 94.2226
# [338]	training's mape: 91.3681	valid_1's mape: 94.1936
# [339]	training's mape: 91.3686	valid_1's mape: 94.1917
# [340]	training's mape: 91.3394	valid_1's mape: 94.1734
# [341]	training's mape: 90.9459	valid_1's mape: 93.5579
# [342]	training's mape: 90.9063	valid_1's mape: 93.5545
# [343]	training's mape: 90.8526	valid_1's mape: 93.6036
# [344]	training's mape: 90.7715	valid_1's mape: 93.5013
# [345]	training's mape: 90.7013	valid_1's mape: 93.4571
# [346]	training's mape: 90.7268	valid_1's mape: 93.6037
# [347]	training's mape: 90.7651	valid_1's mape: 93.6528
# [348]	training's mape: 90.5684	valid_1's mape: 93.5275
# [349]	training's mape: 90.5651	valid_1's mape: 93.5309
# [350]	training's mape: 90.545	valid_1's mape: 93.5225
# [351]	training's mape: 90.5052	valid_1's mape: 93.4765
# [352]	training's mape: 90.497	valid_1's mape: 93.4917
# [353]	training's mape: 90.5125	valid_1's mape: 93.5239
# [354]	training's mape: 90.5208	valid_1's mape: 93.5436
# [355]	training's mape: 90.0665	valid_1's mape: 93.0244
# [356]	training's mape: 90.0172	valid_1's mape: 92.888
# [357]	training's mape: 89.9735	valid_1's mape: 92.8852
# [358]	training's mape: 89.9647	valid_1's mape: 92.8746
# [359]	training's mape: 89.8482	valid_1's mape: 92.8819
# [360]	training's mape: 89.8237	valid_1's mape: 92.8571
# [361]	training's mape: 89.7194	valid_1's mape: 92.8806
# [362]	training's mape: 89.6938	valid_1's mape: 92.8456
# [363]	training's mape: 89.5889	valid_1's mape: 92.7581
# [364]	training's mape: 89.5318	valid_1's mape: 92.8387
# [365]	training's mape: 89.5037	valid_1's mape: 92.8133
# [366]	training's mape: 89.548	valid_1's mape: 92.9092
# [367]	training's mape: 89.5321	valid_1's mape: 92.893
# [368]	training's mape: 89.4901	valid_1's mape: 92.8532
# [369]	training's mape: 89.4853	valid_1's mape: 92.8236
# [370]	training's mape: 89.3293	valid_1's mape: 92.7961
# [371]	training's mape: 89.2954	valid_1's mape: 92.7774
# [372]	training's mape: 89.2662	valid_1's mape: 92.7752
# [373]	training's mape: 89.2809	valid_1's mape: 92.7774
# [374]	training's mape: 89.27	valid_1's mape: 92.7881
# [375]	training's mape: 89.2046	valid_1's mape: 92.7012
# [376]	training's mape: 89.2213	valid_1's mape: 92.7153
# [377]	training's mape: 89.0837	valid_1's mape: 92.483
# [378]	training's mape: 89.0319	valid_1's mape: 92.4504
# [379]	training's mape: 89.031	valid_1's mape: 92.4256
# [380]	training's mape: 89.0109	valid_1's mape: 92.3781
# [381]	training's mape: 88.9852	valid_1's mape: 92.3211
# [382]	training's mape: 88.9122	valid_1's mape: 92.2983
# [383]	training's mape: 88.8899	valid_1's mape: 92.2741
# [384]	training's mape: 88.8789	valid_1's mape: 92.462
# [385]	training's mape: 88.8463	valid_1's mape: 92.4113
# [386]	training's mape: 88.7082	valid_1's mape: 92.2435
# [387]	training's mape: 88.6883	valid_1's mape: 92.2091
# [388]	training's mape: 88.6894	valid_1's mape: 92.301
# [389]	training's mape: 88.7	valid_1's mape: 92.3118
# [390]	training's mape: 88.6882	valid_1's mape: 92.1882
# [391]	training's mape: 88.6065	valid_1's mape: 92.2205
# [392]	training's mape: 88.6205	valid_1's mape: 92.2309
# [393]	training's mape: 88.5872	valid_1's mape: 92.1917
# [394]	training's mape: 88.5062	valid_1's mape: 92.0797
# [395]	training's mape: 88.5463	valid_1's mape: 92.1505
# [396]	training's mape: 88.3964	valid_1's mape: 92.1337
# [397]	training's mape: 88.3959	valid_1's mape: 92.2096
# [398]	training's mape: 88.3696	valid_1's mape: 92.1844
# [399]	training's mape: 88.2323	valid_1's mape: 91.9259
# [400]	training's mape: 88.2311	valid_1's mape: 91.926
# [401]	training's mape: 88.2116	valid_1's mape: 91.9126
# [402]	training's mape: 88.2017	valid_1's mape: 91.9069
# [403]	training's mape: 88.2062	valid_1's mape: 91.9183
# [404]	training's mape: 88.1845	valid_1's mape: 91.8756
# [405]	training's mape: 88.1232	valid_1's mape: 91.5908
# [406]	training's mape: 88.1293	valid_1's mape: 91.6422
# [407]	training's mape: 88.1091	valid_1's mape: 91.6179
# [408]	training's mape: 88.161	valid_1's mape: 91.6585
# [409]	training's mape: 88.1858	valid_1's mape: 91.7001
# [410]	training's mape: 87.857	valid_1's mape: 91.431
# [411]	training's mape: 87.8393	valid_1's mape: 91.4346
# [412]	training's mape: 87.7953	valid_1's mape: 91.3201
# [413]	training's mape: 87.7694	valid_1's mape: 91.3046
# [414]	training's mape: 87.7612	valid_1's mape: 91.289
# [415]	training's mape: 87.6824	valid_1's mape: 91.2783
# [416]	training's mape: 87.64	valid_1's mape: 91.2375
# [417]	training's mape: 87.5302	valid_1's mape: 91.2508
# [418]	training's mape: 87.5052	valid_1's mape: 91.263
# [419]	training's mape: 87.4883	valid_1's mape: 91.2592
# [420]	training's mape: 87.4795	valid_1's mape: 91.2782
# [421]	training's mape: 87.4811	valid_1's mape: 91.3061
# [422]	training's mape: 87.493	valid_1's mape: 91.3118
# [423]	training's mape: 87.4538	valid_1's mape: 91.3787
# [424]	training's mape: 87.3843	valid_1's mape: 91.4233
# [425]	training's mape: 87.387	valid_1's mape: 91.4603
# [426]	training's mape: 87.2983	valid_1's mape: 91.3002
# [427]	training's mape: 87.1731	valid_1's mape: 91.15
# [428]	training's mape: 87.2139	valid_1's mape: 91.2168
# [429]	training's mape: 87.1864	valid_1's mape: 91.2161
# [430]	training's mape: 87.0722	valid_1's mape: 91.2195
# [431]	training's mape: 87.0431	valid_1's mape: 91.1716
# [432]	training's mape: 87.0141	valid_1's mape: 91.1921
# [433]	training's mape: 86.9958	valid_1's mape: 91.1778
# [434]	training's mape: 86.991	valid_1's mape: 91.1727
# [435]	training's mape: 87.0124	valid_1's mape: 91.1918
# [436]	training's mape: 86.9553	valid_1's mape: 91.2294
# [437]	training's mape: 86.7494	valid_1's mape: 90.8993
# [438]	training's mape: 86.746	valid_1's mape: 90.9086
# [439]	training's mape: 86.6949	valid_1's mape: 90.8871
# [440]	training's mape: 86.6389	valid_1's mape: 90.8526
# [441]	training's mape: 86.6384	valid_1's mape: 90.8282
# [442]	training's mape: 86.6448	valid_1's mape: 90.8368
# [443]	training's mape: 86.6019	valid_1's mape: 90.7962
# [444]	training's mape: 86.5552	valid_1's mape: 90.8227
# [445]	training's mape: 86.5814	valid_1's mape: 90.8337
# [446]	training's mape: 86.5759	valid_1's mape: 90.8296
# [447]	training's mape: 86.5701	valid_1's mape: 90.8337
# [448]	training's mape: 86.4493	valid_1's mape: 90.712
# [449]	training's mape: 86.4481	valid_1's mape: 90.7176
# [450]	training's mape: 86.4614	valid_1's mape: 90.6748
# [451]	training's mape: 86.4141	valid_1's mape: 90.639
# [452]	training's mape: 86.4114	valid_1's mape: 90.6309
# [453]	training's mape: 86.3475	valid_1's mape: 90.8202
# [454]	training's mape: 86.3226	valid_1's mape: 90.7877
# [455]	training's mape: 86.2209	valid_1's mape: 90.7156
# [456]	training's mape: 86.2094	valid_1's mape: 90.7139
# [457]	training's mape: 86.2263	valid_1's mape: 90.7406
# [458]	training's mape: 86.1715	valid_1's mape: 90.7961
# [459]	training's mape: 86.1971	valid_1's mape: 90.8344
# [460]	training's mape: 86.2048	valid_1's mape: 90.9337
# [461]	training's mape: 86.207	valid_1's mape: 90.9495
# [462]	training's mape: 86.1595	valid_1's mape: 90.8928
# [463]	training's mape: 86.1478	valid_1's mape: 90.8891
# [464]	training's mape: 86.1137	valid_1's mape: 90.871
# [465]	training's mape: 86.1253	valid_1's mape: 90.8802
# [466]	training's mape: 86.1049	valid_1's mape: 90.8519
# [467]	training's mape: 86.0962	valid_1's mape: 90.856
# [468]	training's mape: 86.0592	valid_1's mape: 90.8448
# [469]	training's mape: 85.9535	valid_1's mape: 90.4759
# [470]	training's mape: 85.9086	valid_1's mape: 90.5061
# [471]	training's mape: 85.9012	valid_1's mape: 90.4581
# [472]	training's mape: 85.9186	valid_1's mape: 90.4942
# [473]	training's mape: 85.9341	valid_1's mape: 90.4505
# [474]	training's mape: 85.9238	valid_1's mape: 90.4294
# [475]	training's mape: 85.7566	valid_1's mape: 90.062
# [476]	training's mape: 85.7806	valid_1's mape: 90.0815
# [477]	training's mape: 85.7707	valid_1's mape: 90.0819
# [478]	training's mape: 85.7984	valid_1's mape: 90.0706
# [479]	training's mape: 85.7821	valid_1's mape: 90.0544
# [480]	training's mape: 85.7828	valid_1's mape: 90.0594
# [481]	training's mape: 85.7529	valid_1's mape: 90.0598
# [482]	training's mape: 85.7467	valid_1's mape: 90.0561
# [483]	training's mape: 85.7653	valid_1's mape: 90.0864
# [484]	training's mape: 85.761	valid_1's mape: 90.1223
# [485]	training's mape: 85.4604	valid_1's mape: 89.8956
# [486]	training's mape: 85.4606	valid_1's mape: 89.9071
# [487]	training's mape: 85.4684	valid_1's mape: 89.9266
# [488]	training's mape: 85.352	valid_1's mape: 89.7533
# [489]	training's mape: 85.2801	valid_1's mape: 89.7782
# [490]	training's mape: 85.2906	valid_1's mape: 89.7468
# [491]	training's mape: 85.2543	valid_1's mape: 89.7158
# [492]	training's mape: 85.2447	valid_1's mape: 89.8246
# [493]	training's mape: 85.2424	valid_1's mape: 89.83
# [494]	training's mape: 85.2404	valid_1's mape: 89.8272
# [495]	training's mape: 85.2391	valid_1's mape: 89.8328
# [496]	training's mape: 85.1939	valid_1's mape: 89.7697
# [497]	training's mape: 85.1884	valid_1's mape: 89.7637
# [498]	training's mape: 85.0581	valid_1's mape: 89.8018
# [499]	training's mape: 85.0963	valid_1's mape: 89.858
# [500]	training's mape: 85.1127	valid_1's mape: 89.8857
# [501]	training's mape: 85.1301	valid_1's mape: 89.8983
# [502]	training's mape: 85.1037	valid_1's mape: 89.8457
# [503]	training's mape: 85.0845	valid_1's mape: 89.8512
# [504]	training's mape: 85.0612	valid_1's mape: 89.7894
# [505]	training's mape: 85.0318	valid_1's mape: 89.7329
# [506]	training's mape: 85.0216	valid_1's mape: 89.7246
# [507]	training's mape: 85.008	valid_1's mape: 89.721
# [508]	training's mape: 85.0131	valid_1's mape: 89.7364
# [509]	training's mape: 84.9846	valid_1's mape: 89.6923
# [510]	training's mape: 84.8969	valid_1's mape: 89.5996
# [511]	training's mape: 84.8669	valid_1's mape: 89.5605
# [512]	training's mape: 84.8204	valid_1's mape: 89.5426
# [513]	training's mape: 84.7206	valid_1's mape: 89.5908
# [514]	training's mape: 84.7205	valid_1's mape: 89.592
# [515]	training's mape: 84.7011	valid_1's mape: 89.5719
# [516]	training's mape: 84.6347	valid_1's mape: 89.4913
# [517]	training's mape: 84.594	valid_1's mape: 89.5523
# [518]	training's mape: 84.5902	valid_1's mape: 89.7439
# [519]	training's mape: 84.6406	valid_1's mape: 89.7271
# [520]	training's mape: 84.6565	valid_1's mape: 89.758
# [521]	training's mape: 84.6587	valid_1's mape: 89.7725
# [522]	training's mape: 84.6585	valid_1's mape: 89.7752
# [523]	training's mape: 84.6627	valid_1's mape: 89.7743
# [524]	training's mape: 84.6445	valid_1's mape: 89.753
# [525]	training's mape: 84.6462	valid_1's mape: 89.7555
# [526]	training's mape: 84.6206	valid_1's mape: 89.7054
# [527]	training's mape: 84.5339	valid_1's mape: 89.7081
# [528]	training's mape: 84.4983	valid_1's mape: 89.6026
# [529]	training's mape: 84.4454	valid_1's mape: 89.5465
# [530]	training's mape: 84.447	valid_1's mape: 89.5607
# [531]	training's mape: 84.4521	valid_1's mape: 89.5805
# [532]	training's mape: 84.398	valid_1's mape: 89.5503
# [533]	training's mape: 84.4316	valid_1's mape: 89.5815
# [534]	training's mape: 84.4427	valid_1's mape: 89.6072
# [535]	training's mape: 84.2754	valid_1's mape: 89.4989
# [536]	training's mape: 84.2706	valid_1's mape: 89.5076
# [537]	training's mape: 84.2155	valid_1's mape: 89.51
# [538]	training's mape: 84.2433	valid_1's mape: 89.5226
# [539]	training's mape: 84.2462	valid_1's mape: 89.5211
# [540]	training's mape: 84.1637	valid_1's mape: 89.5434
# [541]	training's mape: 84.1512	valid_1's mape: 89.5441
# [542]	training's mape: 84.0506	valid_1's mape: 89.4616
# [543]	training's mape: 83.9928	valid_1's mape: 89.4268
# [544]	training's mape: 84.0211	valid_1's mape: 89.4559
# [545]	training's mape: 84.0049	valid_1's mape: 89.4476
# [546]	training's mape: 84.0106	valid_1's mape: 89.4568
# [547]	training's mape: 83.9562	valid_1's mape: 89.7391
# [548]	training's mape: 83.92	valid_1's mape: 89.6742
# [549]	training's mape: 83.8945	valid_1's mape: 89.7047
# [550]	training's mape: 83.8247	valid_1's mape: 89.6152
# [551]	training's mape: 83.754	valid_1's mape: 89.6945
# [552]	training's mape: 83.6958	valid_1's mape: 89.6097
# [553]	training's mape: 83.6697	valid_1's mape: 89.5118
# [554]	training's mape: 83.6256	valid_1's mape: 89.5065
# [555]	training's mape: 83.615	valid_1's mape: 89.4867
# [556]	training's mape: 83.5614	valid_1's mape: 89.4287
# [557]	training's mape: 83.4463	valid_1's mape: 89.3508
# [558]	training's mape: 83.4303	valid_1's mape: 89.3338
# [559]	training's mape: 83.4014	valid_1's mape: 89.3233
# [560]	training's mape: 83.3639	valid_1's mape: 89.2798
# [561]	training's mape: 83.3398	valid_1's mape: 89.3152
# [562]	training's mape: 83.27	valid_1's mape: 89.0526
# [563]	training's mape: 83.2975	valid_1's mape: 89.0972
# [564]	training's mape: 83.2925	valid_1's mape: 89.0944
# [565]	training's mape: 83.3022	valid_1's mape: 89.0775
# [566]	training's mape: 83.3138	valid_1's mape: 89.0868
# [567]	training's mape: 83.3272	valid_1's mape: 89.1078
# [568]	training's mape: 83.2966	valid_1's mape: 89.0854
# [569]	training's mape: 83.2322	valid_1's mape: 89.2102
# [570]	training's mape: 83.2232	valid_1's mape: 89.2008
# [571]	training's mape: 83.2279	valid_1's mape: 89.2163
# [572]	training's mape: 83.1881	valid_1's mape: 89.1533
# [573]	training's mape: 83.0768	valid_1's mape: 89.108
# [574]	training's mape: 83.0497	valid_1's mape: 89.1644
# [575]	training's mape: 83.017	valid_1's mape: 89.1363
# [576]	training's mape: 82.995	valid_1's mape: 89.1194
# [577]	training's mape: 82.9947	valid_1's mape: 89.1535
# [578]	training's mape: 82.982	valid_1's mape: 89.1364
# [579]	training's mape: 82.9398	valid_1's mape: 89.0551
# [580]	training's mape: 82.9052	valid_1's mape: 89.1301
# [581]	training's mape: 82.892	valid_1's mape: 89.1191
# [582]	training's mape: 82.9089	valid_1's mape: 89.1603
# [583]	training's mape: 82.8569	valid_1's mape: 89.1128
# [584]	training's mape: 82.8786	valid_1's mape: 89.1706
# [585]	training's mape: 82.8565	valid_1's mape: 89.1322
# [586]	training's mape: 82.7645	valid_1's mape: 89.0121
# [587]	training's mape: 82.7758	valid_1's mape: 89.1047
# [588]	training's mape: 82.7472	valid_1's mape: 89.0644
# [589]	training's mape: 82.6157	valid_1's mape: 89.0266
# [590]	training's mape: 82.603	valid_1's mape: 89.0181
# [591]	training's mape: 82.5757	valid_1's mape: 89.0027
# [592]	training's mape: 82.6028	valid_1's mape: 89.1195
# [593]	training's mape: 82.618	valid_1's mape: 89.1404
# [594]	training's mape: 82.5449	valid_1's mape: 89.0955
# [595]	training's mape: 82.4958	valid_1's mape: 89.0663
# [596]	training's mape: 82.4981	valid_1's mape: 89.0655
# [597]	training's mape: 82.4652	valid_1's mape: 89.0368
# [598]	training's mape: 82.487	valid_1's mape: 89.0773
# [599]	training's mape: 82.4055	valid_1's mape: 88.9738
# [600]	training's mape: 82.3842	valid_1's mape: 88.9541
# [601]	training's mape: 82.3552	valid_1's mape: 88.9132
# [602]	training's mape: 82.377	valid_1's mape: 88.9468
# [603]	training's mape: 82.3739	valid_1's mape: 88.9429
# [604]	training's mape: 82.3243	valid_1's mape: 88.8863
# [605]	training's mape: 82.3403	valid_1's mape: 88.948
# [606]	training's mape: 82.3014	valid_1's mape: 88.8919
# [607]	training's mape: 82.323	valid_1's mape: 88.8952
# [608]	training's mape: 82.3207	valid_1's mape: 88.8994
# [609]	training's mape: 82.3194	valid_1's mape: 88.9167
# [610]	training's mape: 82.3151	valid_1's mape: 88.9265
# [611]	training's mape: 82.2643	valid_1's mape: 88.9192
# [612]	training's mape: 82.2407	valid_1's mape: 88.9031
# [613]	training's mape: 82.2443	valid_1's mape: 88.9204
# [614]	training's mape: 82.2476	valid_1's mape: 88.9347
# [615]	training's mape: 82.2413	valid_1's mape: 88.9462
# [616]	training's mape: 82.2207	valid_1's mape: 88.9044
# [617]	training's mape: 82.2285	valid_1's mape: 88.9286
# [618]	training's mape: 82.2104	valid_1's mape: 88.8985
# [619]	training's mape: 82.1907	valid_1's mape: 88.8784
# [620]	training's mape: 82.185	valid_1's mape: 88.8662
# [621]	training's mape: 82.1815	valid_1's mape: 88.8595
# [622]	training's mape: 82.1762	valid_1's mape: 88.8673
# [623]	training's mape: 82.1813	valid_1's mape: 88.8726
# [624]	training's mape: 82.1908	valid_1's mape: 88.8471
# [625]	training's mape: 82.1313	valid_1's mape: 88.685
# [626]	training's mape: 82.1067	valid_1's mape: 88.6421
# [627]	training's mape: 82.1005	valid_1's mape: 88.6246
# [628]	training's mape: 82.0781	valid_1's mape: 88.6134
# [629]	training's mape: 82.0759	valid_1's mape: 88.6352
# [630]	training's mape: 82.0494	valid_1's mape: 88.6433
# [631]	training's mape: 82.0467	valid_1's mape: 88.6058
# [632]	training's mape: 82.0473	valid_1's mape: 88.6021
# [633]	training's mape: 82.0616	valid_1's mape: 88.626
# [634]	training's mape: 82.0416	valid_1's mape: 88.6007
# [635]	training's mape: 82.0416	valid_1's mape: 88.6135
# [636]	training's mape: 82.0156	valid_1's mape: 88.5808
# [637]	training's mape: 81.9905	valid_1's mape: 88.552
# [638]	training's mape: 81.9785	valid_1's mape: 88.5748
# [639]	training's mape: 81.9401	valid_1's mape: 88.5957
# [640]	training's mape: 81.9057	valid_1's mape: 88.5711
# [641]	training's mape: 81.9307	valid_1's mape: 88.6239
# [642]	training's mape: 81.9072	valid_1's mape: 88.6128
# [643]	training's mape: 81.8929	valid_1's mape: 88.6101
# [644]	training's mape: 81.8235	valid_1's mape: 88.5394
# [645]	training's mape: 81.8123	valid_1's mape: 88.5398
# [646]	training's mape: 81.7872	valid_1's mape: 88.5943
# [647]	training's mape: 81.812	valid_1's mape: 88.6261
# [648]	training's mape: 81.8045	valid_1's mape: 88.6156
# [649]	training's mape: 81.7725	valid_1's mape: 88.5655
# [650]	training's mape: 81.7684	valid_1's mape: 88.5743
# [651]	training's mape: 81.7686	valid_1's mape: 88.57
# [652]	training's mape: 81.741	valid_1's mape: 88.5166
# [653]	training's mape: 81.7033	valid_1's mape: 88.6689
# [654]	training's mape: 81.6874	valid_1's mape: 88.6045
# [655]	training's mape: 81.6815	valid_1's mape: 88.4933
# [656]	training's mape: 81.7119	valid_1's mape: 88.5392
# [657]	training's mape: 81.692	valid_1's mape: 88.5553
# [658]	training's mape: 81.6558	valid_1's mape: 88.5132
# [659]	training's mape: 81.6132	valid_1's mape: 88.5063
# [660]	training's mape: 81.6112	valid_1's mape: 88.5288
# [661]	training's mape: 81.6036	valid_1's mape: 88.5458
# [662]	training's mape: 81.6333	valid_1's mape: 88.5791
# [663]	training's mape: 81.62	valid_1's mape: 88.5586
# [664]	training's mape: 81.611	valid_1's mape: 88.5344
# [665]	training's mape: 81.6149	valid_1's mape: 88.553
# [666]	training's mape: 81.6132	valid_1's mape: 88.5557
# [667]	training's mape: 81.5777	valid_1's mape: 88.2332
# [668]	training's mape: 81.5864	valid_1's mape: 88.2414
# [669]	training's mape: 81.5892	valid_1's mape: 88.2475
# [670]	training's mape: 81.5881	valid_1's mape: 88.2082
# [671]	training's mape: 81.558	valid_1's mape: 88.2029
# [672]	training's mape: 81.4324	valid_1's mape: 88.2081
# [673]	training's mape: 81.4271	valid_1's mape: 88.2002
# [674]	training's mape: 81.4015	valid_1's mape: 88.1608
# [675]	training's mape: 81.3659	valid_1's mape: 88.1367
# [676]	training's mape: 81.3624	valid_1's mape: 88.1136
# [677]	training's mape: 81.1863	valid_1's mape: 87.8293
# [678]	training's mape: 81.1567	valid_1's mape: 87.8122
# [679]	training's mape: 81.1205	valid_1's mape: 87.8388
# [680]	training's mape: 81.1185	valid_1's mape: 87.763
# [681]	training's mape: 81.1002	valid_1's mape: 87.7545
# [682]	training's mape: 81.105	valid_1's mape: 87.7728
# [683]	training's mape: 81.1187	valid_1's mape: 87.7074
# [684]	training's mape: 81.0296	valid_1's mape: 87.6466
# [685]	training's mape: 81.0236	valid_1's mape: 87.6507
# [686]	training's mape: 81.0266	valid_1's mape: 87.663
# [687]	training's mape: 81.0228	valid_1's mape: 87.6572
# [688]	training's mape: 81.0194	valid_1's mape: 87.6709
# [689]	training's mape: 81.0223	valid_1's mape: 87.6781
# [690]	training's mape: 81.0269	valid_1's mape: 87.6937
# [691]	training's mape: 80.997	valid_1's mape: 87.6524
# [692]	training's mape: 80.9964	valid_1's mape: 87.6546
# [693]	training's mape: 80.998	valid_1's mape: 87.651
# [694]	training's mape: 80.9891	valid_1's mape: 87.6324
# [695]	training's mape: 80.8773	valid_1's mape: 87.5348
# [696]	training's mape: 80.8283	valid_1's mape: 87.4389
# [697]	training's mape: 80.8316	valid_1's mape: 87.4479
# [698]	training's mape: 80.8311	valid_1's mape: 87.442
# [699]	training's mape: 80.8484	valid_1's mape: 87.4164
# [700]	training's mape: 80.7753	valid_1's mape: 87.4211
# [701]	training's mape: 80.7717	valid_1's mape: 87.4217
# [702]	training's mape: 80.7327	valid_1's mape: 87.3974
# [703]	training's mape: 80.7391	valid_1's mape: 87.4111
# [704]	training's mape: 80.7153	valid_1's mape: 87.3774
# [705]	training's mape: 80.6933	valid_1's mape: 87.3178
# [706]	training's mape: 80.6843	valid_1's mape: 87.321
# [707]	training's mape: 80.6813	valid_1's mape: 87.3346
# [708]	training's mape: 80.5325	valid_1's mape: 87.2324
# [709]	training's mape: 80.523	valid_1's mape: 87.2266
# [710]	training's mape: 80.5471	valid_1's mape: 87.2665
# [711]	training's mape: 80.511	valid_1's mape: 87.23
# [712]	training's mape: 80.5319	valid_1's mape: 87.2535
# [713]	training's mape: 80.5008	valid_1's mape: 87.2506
# [714]	training's mape: 80.4909	valid_1's mape: 87.3098
# [715]	training's mape: 80.4791	valid_1's mape: 87.313
# [716]	training's mape: 80.4664	valid_1's mape: 87.3056
# [717]	training's mape: 80.4685	valid_1's mape: 87.2723
# [718]	training's mape: 80.4068	valid_1's mape: 87.2422
# [719]	training's mape: 80.4112	valid_1's mape: 87.2621
# [720]	training's mape: 80.3966	valid_1's mape: 87.2423
# [721]	training's mape: 80.3961	valid_1's mape: 87.2448
# [722]	training's mape: 80.3884	valid_1's mape: 87.2108
# [723]	training's mape: 80.3734	valid_1's mape: 87.1766
# [724]	training's mape: 80.3304	valid_1's mape: 87.1203
# [725]	training's mape: 80.3291	valid_1's mape: 87.1208
# [726]	training's mape: 80.3689	valid_1's mape: 87.1176
# [727]	training's mape: 80.2535	valid_1's mape: 87.0872
# [728]	training's mape: 80.2568	valid_1's mape: 87.1118
# [729]	training's mape: 80.2896	valid_1's mape: 87.1197
# [730]	training's mape: 80.3078	valid_1's mape: 87.145
# [731]	training's mape: 80.2602	valid_1's mape: 87.0845
# [732]	training's mape: 80.2399	valid_1's mape: 87.0486
# [733]	training's mape: 80.2152	valid_1's mape: 86.9665
# [734]	training's mape: 80.2116	valid_1's mape: 86.9519
# [735]	training's mape: 80.1751	valid_1's mape: 87.0122
# [736]	training's mape: 80.1764	valid_1's mape: 87.0359
# [737]	training's mape: 80.1733	valid_1's mape: 87.0327
# [738]	training's mape: 80.1837	valid_1's mape: 87.0625
# [739]	training's mape: 80.1141	valid_1's mape: 87.1152
# [740]	training's mape: 80.1218	valid_1's mape: 87.1371
# [741]	training's mape: 80.11	valid_1's mape: 87.0829
# [742]	training's mape: 80.0148	valid_1's mape: 87.0764
# [743]	training's mape: 80.0194	valid_1's mape: 87.0153
# [744]	training's mape: 80.0216	valid_1's mape: 87.0314
# [745]	training's mape: 79.977	valid_1's mape: 87.0133
# [746]	training's mape: 79.9558	valid_1's mape: 86.9987
# [747]	training's mape: 79.9652	valid_1's mape: 87.025
# [748]	training's mape: 79.9411	valid_1's mape: 86.9617
# [749]	training's mape: 79.9436	valid_1's mape: 87.0602
# [750]	training's mape: 79.9397	valid_1's mape: 87.0559
# [751]	training's mape: 79.9486	valid_1's mape: 87.0777
# [752]	training's mape: 79.9135	valid_1's mape: 87.0442
# [753]	training's mape: 79.9098	valid_1's mape: 87.0356
# [754]	training's mape: 79.9183	valid_1's mape: 87.0551
# [755]	training's mape: 79.9012	valid_1's mape: 87.0393
# [756]	training's mape: 79.8836	valid_1's mape: 87.0153
# [757]	training's mape: 79.7413	valid_1's mape: 86.9263
# [758]	training's mape: 79.7028	valid_1's mape: 86.9356
# [759]	training's mape: 79.6957	valid_1's mape: 87.0243
# [760]	training's mape: 79.699	valid_1's mape: 87.0409
# [761]	training's mape: 79.6906	valid_1's mape: 87.0524
# [762]	training's mape: 79.7066	valid_1's mape: 87.0763
# [763]	training's mape: 79.71	valid_1's mape: 87.1004
# [764]	training's mape: 79.7081	valid_1's mape: 87.1074
# [765]	training's mape: 79.6879	valid_1's mape: 87.0828
# [766]	training's mape: 79.6787	valid_1's mape: 87.0684
# [767]	training's mape: 79.6403	valid_1's mape: 86.9971
# [768]	training's mape: 79.644	valid_1's mape: 86.9641
# [769]	training's mape: 79.6369	valid_1's mape: 86.9805
# [770]	training's mape: 79.6357	valid_1's mape: 86.9871
# [771]	training's mape: 79.6434	valid_1's mape: 87.0046
# [772]	training's mape: 79.7806	valid_1's mape: 86.9626
# [773]	training's mape: 79.6079	valid_1's mape: 86.8354
# [774]	training's mape: 79.5731	valid_1's mape: 86.7881
# [775]	training's mape: 79.5514	valid_1's mape: 86.7658
# [776]	training's mape: 79.5435	valid_1's mape: 86.7733
# [777]	training's mape: 79.5235	valid_1's mape: 86.7522
# [778]	training's mape: 79.5013	valid_1's mape: 86.6615
# [779]	training's mape: 79.488	valid_1's mape: 86.6338
# [780]	training's mape: 79.4371	valid_1's mape: 86.5713
# [781]	training's mape: 79.4179	valid_1's mape: 86.574
# [782]	training's mape: 79.3752	valid_1's mape: 86.523
# [783]	training's mape: 79.4132	valid_1's mape: 86.5476
# [784]	training's mape: 79.409	valid_1's mape: 86.5472
# [785]	training's mape: 79.3979	valid_1's mape: 86.5131
# [786]	training's mape: 79.4009	valid_1's mape: 86.5558
# [787]	training's mape: 79.3697	valid_1's mape: 86.5171
# [788]	training's mape: 79.3588	valid_1's mape: 86.9831
# [789]	training's mape: 79.3904	valid_1's mape: 87.0071
# [790]	training's mape: 79.3381	valid_1's mape: 86.8136
# [791]	training's mape: 79.3613	valid_1's mape: 86.8538
# [792]	training's mape: 79.3623	valid_1's mape: 86.894
# [793]	training's mape: 79.3408	valid_1's mape: 86.8222
# [794]	training's mape: 79.3028	valid_1's mape: 86.7705
# [795]	training's mape: 79.2571	valid_1's mape: 86.7562
# [796]	training's mape: 79.2713	valid_1's mape: 86.7594
# [797]	training's mape: 79.2679	valid_1's mape: 86.7709
# [798]	training's mape: 79.2638	valid_1's mape: 86.7663
# [799]	training's mape: 79.2766	valid_1's mape: 86.8068
# [800]	training's mape: 79.2742	valid_1's mape: 86.8287
# [801]	training's mape: 79.2618	valid_1's mape: 86.8382
# [802]	training's mape: 79.2558	valid_1's mape: 86.833
# [803]	training's mape: 79.2365	valid_1's mape: 86.8249
# [804]	training's mape: 79.2127	valid_1's mape: 86.5929
# [805]	training's mape: 79.1873	valid_1's mape: 86.5185
# [806]	training's mape: 79.1716	valid_1's mape: 86.5163
# [807]	training's mape: 79.1659	valid_1's mape: 86.5136
# [808]	training's mape: 79.1662	valid_1's mape: 86.5214
# [809]	training's mape: 79.1462	valid_1's mape: 86.5279
# [810]	training's mape: 79.2454	valid_1's mape: 86.6039
# [811]	training's mape: 79.2419	valid_1's mape: 86.5861
# [812]	training's mape: 79.2504	valid_1's mape: 86.6124
# [813]	training's mape: 79.1447	valid_1's mape: 86.4463
# [814]	training's mape: 79.1472	valid_1's mape: 86.4423
# [815]	training's mape: 79.1068	valid_1's mape: 86.4451
# [816]	training's mape: 79.1133	valid_1's mape: 86.4478
# [817]	training's mape: 79.0372	valid_1's mape: 86.4071
# [818]	training's mape: 79.0093	valid_1's mape: 86.3848
# [819]	training's mape: 79.024	valid_1's mape: 86.4099
# [820]	training's mape: 79.0137	valid_1's mape: 86.3977
# [821]	training's mape: 79.0182	valid_1's mape: 86.4046
# [822]	training's mape: 79.0148	valid_1's mape: 86.398
# [823]	training's mape: 79.0197	valid_1's mape: 86.4091
# [824]	training's mape: 79.0155	valid_1's mape: 86.4075
# [825]	training's mape: 79.0158	valid_1's mape: 86.4115
# [826]	training's mape: 79.0168	valid_1's mape: 86.415
# [827]	training's mape: 79.0455	valid_1's mape: 86.4238
# [828]	training's mape: 79.0304	valid_1's mape: 86.4353
# [829]	training's mape: 78.9952	valid_1's mape: 86.4217
# [830]	training's mape: 79.0187	valid_1's mape: 86.5271
# [831]	training's mape: 79.0215	valid_1's mape: 86.5337
# [832]	training's mape: 78.9843	valid_1's mape: 86.4993
# [833]	training's mape: 78.9696	valid_1's mape: 86.4914
# [834]	training's mape: 78.9516	valid_1's mape: 86.4852
# [835]	training's mape: 78.9138	valid_1's mape: 86.4525
# [836]	training's mape: 78.9216	valid_1's mape: 86.4429
# [837]	training's mape: 78.9445	valid_1's mape: 86.4668
# [838]	training's mape: 78.9239	valid_1's mape: 86.4759
# [839]	training's mape: 78.8818	valid_1's mape: 86.2722
# [840]	training's mape: 78.8744	valid_1's mape: 86.2798
# [841]	training's mape: 78.8762	valid_1's mape: 86.3228
# [842]	training's mape: 78.9048	valid_1's mape: 86.3605
# [843]	training's mape: 78.8868	valid_1's mape: 86.3508
# [844]	training's mape: 78.891	valid_1's mape: 86.3618
# [845]	training's mape: 78.8253	valid_1's mape: 86.3261
# [846]	training's mape: 78.7941	valid_1's mape: 86.2568
# [847]	training's mape: 78.7648	valid_1's mape: 86.1966
# [848]	training's mape: 78.7221	valid_1's mape: 86.1186
# [849]	training's mape: 78.6378	valid_1's mape: 86.1108
# [850]	training's mape: 78.5635	valid_1's mape: 85.9994
# [851]	training's mape: 78.5467	valid_1's mape: 85.9801
# [852]	training's mape: 78.5567	valid_1's mape: 85.9902
# [853]	training's mape: 78.5248	valid_1's mape: 85.9542
# [854]	training's mape: 78.497	valid_1's mape: 85.9326
# [855]	training's mape: 78.4946	valid_1's mape: 85.9144
# [856]	training's mape: 78.4256	valid_1's mape: 85.7798
# [857]	training's mape: 78.3736	valid_1's mape: 85.7335
# [858]	training's mape: 78.3561	valid_1's mape: 85.7204
# [859]	training's mape: 78.327	valid_1's mape: 86.5293
# [860]	training's mape: 78.3225	valid_1's mape: 86.5265
# [861]	training's mape: 78.3114	valid_1's mape: 86.5461
# [862]	training's mape: 78.3001	valid_1's mape: 86.5125
# [863]	training's mape: 78.3026	valid_1's mape: 86.5356
# [864]	training's mape: 78.2947	valid_1's mape: 86.5554
# [865]	training's mape: 78.2772	valid_1's mape: 86.5251
# [866]	training's mape: 78.273	valid_1's mape: 86.5207
# [867]	training's mape: 78.2619	valid_1's mape: 86.5186
# [868]	training's mape: 78.2523	valid_1's mape: 86.5132
# [869]	training's mape: 78.2546	valid_1's mape: 86.5281
# [870]	training's mape: 78.284	valid_1's mape: 86.5533
# [871]	training's mape: 78.2742	valid_1's mape: 86.534
# [872]	training's mape: 78.2935	valid_1's mape: 86.5402
# [873]	training's mape: 78.2829	valid_1's mape: 86.5313
# [874]	training's mape: 78.2065	valid_1's mape: 86.5309
# [875]	training's mape: 78.1931	valid_1's mape: 86.5286
# [876]	training's mape: 78.1942	valid_1's mape: 86.5312
# [877]	training's mape: 78.1804	valid_1's mape: 86.5152
# [878]	training's mape: 78.1851	valid_1's mape: 86.6018
# [879]	training's mape: 78.1866	valid_1's mape: 86.6158
# [880]	training's mape: 78.1927	valid_1's mape: 86.6566
# [881]	training's mape: 78.181	valid_1's mape: 86.6456
# [882]	training's mape: 78.1978	valid_1's mape: 86.6627
# [883]	training's mape: 78.1782	valid_1's mape: 86.6259
# [884]	training's mape: 78.0776	valid_1's mape: 86.6036
# [885]	training's mape: 78.0825	valid_1's mape: 86.5692
# [886]	training's mape: 78.0855	valid_1's mape: 86.5791
# [887]	training's mape: 78.0738	valid_1's mape: 86.5865
# [888]	training's mape: 78.0892	valid_1's mape: 86.612
# [889]	training's mape: 78.0755	valid_1's mape: 86.5949
# [890]	training's mape: 78.0678	valid_1's mape: 86.5837
# [891]	training's mape: 78.0615	valid_1's mape: 86.577
# [892]	training's mape: 78.0504	valid_1's mape: 86.5852
# [893]	training's mape: 78.0356	valid_1's mape: 86.5879
# [894]	training's mape: 78.0372	valid_1's mape: 86.5807
# [895]	training's mape: 78.0502	valid_1's mape: 86.5822
# [896]	training's mape: 78.0511	valid_1's mape: 86.5731
# [897]	training's mape: 78.0284	valid_1's mape: 86.9284
# [898]	training's mape: 78.0261	valid_1's mape: 86.8961
# [899]	training's mape: 78.0129	valid_1's mape: 86.656
# [900]	training's mape: 78.0126	valid_1's mape: 86.6552
# [901]	training's mape: 77.9867	valid_1's mape: 86.6253
# [902]	training's mape: 77.9779	valid_1's mape: 86.6021
# [903]	training's mape: 77.9807	valid_1's mape: 86.6197
# [904]	training's mape: 77.9857	valid_1's mape: 86.6244
# [905]	training's mape: 77.991	valid_1's mape: 86.6456
# [906]	training's mape: 77.988	valid_1's mape: 86.6405
# [907]	training's mape: 77.9755	valid_1's mape: 86.6297
# [908]	training's mape: 77.9724	valid_1's mape: 86.6243
# Early stopping, best iteration is:
# [858]	training's mape: 78.3561	valid_1's mape: 85.7204

# %%
pred = model.predict(X24[train_cols].iloc[val_index])

# %%
print (mean_absolute_error(X24['target'].iloc[val_index],pred))
print (mape(list(X24['target'].iloc[val_index]),pred))
# Out:
# 0.05196879611425471
# 86.94005098212098

# %%
'''
Minmax
lag = 24
0.059817944178918274
123.11137794094829
lag = 48
110
'''
# Out:
# '\nMinmax\nlag = 24\n0.059817944178918274\n123.11137794094829\nlag = 48\n110\n'

# %%
y_final = []
yhat_final = []
y_final_inv = []
yhat_final_inv = []
for ser_id, ser_data in tqdm(test.groupby('series_id')):

    # prepare the data
    if len(ser_data) > lag:
        X, y, scaler = prepare_training_data(ser_data, lag)
        yhat = model.predict(X[train_cols])

        y_final_inv += list(y)
        yhat_final_inv += list(yhat)
        yhat = scaler.inverse_transform(np.array(yhat).reshape(-1, 1)).ravel()  
        y = scaler.inverse_transform(np.array(y).reshape(-1, 1)).ravel()
        y_final += list(y)
        yhat_final += list(yhat)
# Out:
# 100%|██████████| 625/625 [04:40<00:00,  2.23it/s]

# %%
print (mean_absolute_error(y_final_inv,yhat_final_inv))
print (mape(y_final_inv,yhat_final_inv))
print (mape(y_final,yhat_final))
# Out:
# 0.07039256517667151
# 848.4761483355933
# 47.18367279955582

# %%
#explainer = shap.KernelExplainer(model = model.predict, data=X)
#shap_values = explainer.shap_values(X)
import eli5

# %%
train_cols
# Out:
# ['consumption_1',
#  'consumption_2',
#  'consumption_3',
#  'consumption_4',
#  'consumption_5',
#  'consumption_6',
#  'consumption_7',
#  'consumption_8',
#  'consumption_9',
#  'consumption_10',
#  'consumption_11',
#  'consumption_12',
#  'consumption_13',
#  'consumption_14',
#  'consumption_15',
#  'consumption_16',
#  'consumption_17',
#  'consumption_18',
#  'consumption_19',
#  'consumption_20',
#  'consumption_21',
#  'consumption_22',
#  'consumption_23',
#  'consumption_24',
#  'consumption_25',
#  'consumption_26',
#  'consumption_27',
#  'consumption_28',
#  'consumption_29',
#  'consumption_30',
#  'consumption_31',
#  'consumption_32',
#  'consumption_33',
#  'consumption_34',
#  'consumption_35',
#  'consumption_36',
#  'consumption_37',
#  'consumption_38',
#  'consumption_39',
#  'consumption_40',
#  'consumption_41',
#  'consumption_42',
#  'consumption_43',
#  'consumption_44',
#  'consumption_45',
#  'consumption_46',
#  'consumption_47',
#  'consumption_48',
#  'consumption_49',
#  'consumption_50',
#  'consumption_51',
#  'consumption_52',
#  'consumption_53',
#  'consumption_54',
#  'consumption_55',
#  'consumption_56',
#  'consumption_57',
#  'consumption_58',
#  'consumption_59',
#  'consumption_60',
#  'consumption_61',
#  'consumption_62',
#  'consumption_63',
#  'consumption_64',
#  'consumption_65',
#  'consumption_66',
#  'consumption_67',
#  'consumption_68',
#  'consumption_69',
#  'consumption_70',
#  'consumption_71',
#  'consumption_72',
#  'surface',
#  'base_temp',
#  'day_of_week',
#  'is_off']

# %%
importances = model.feature_importance()
indices = np.argsort(importances)[::-1]

for i in range(len(train_cols)):
    print (train_cols[indices[i]], importances[indices[i]])
# Out:
# consumption_1 2075
# consumption_24 1356
# consumption_72 878
# consumption_48 853
# day_of_week 829
# consumption_2 823
# consumption_25 801
# consumption_49 628
# consumption_23 589
# consumption_26 548
# surface 507
# consumption_3 451
# consumption_71 443
# consumption_13 391
# consumption_50 385
# consumption_4 368
# consumption_12 365
# consumption_47 359
# consumption_27 340
# consumption_6 339
# consumption_22 336
# consumption_18 334
# consumption_11 309
# consumption_36 301
# consumption_14 295
# consumption_51 293
# consumption_70 292
# consumption_60 289
# consumption_19 279
# consumption_5 276
# consumption_28 271
# consumption_16 271
# consumption_21 270
# consumption_17 264
# consumption_10 256
# consumption_46 255
# consumption_7 251
# consumption_8 249
# consumption_59 249
# consumption_66 248
# consumption_52 240
# consumption_45 239
# consumption_69 237
# consumption_61 234
# consumption_20 234
# consumption_43 229
# consumption_37 227
# consumption_54 222
# consumption_35 218
# consumption_9 216
# consumption_68 215
# consumption_65 215
# consumption_38 213
# consumption_41 212
# consumption_57 196
# consumption_15 196
# consumption_31 195
# consumption_67 195
# consumption_29 191
# consumption_34 185
# consumption_42 182
# consumption_64 181
# consumption_44 181
# consumption_55 180
# consumption_30 177
# consumption_62 176
# consumption_58 175
# consumption_56 174
# consumption_40 172
# consumption_53 172
# consumption_63 168
# consumption_32 167
# consumption_39 160
# consumption_33 151
# is_off 81
# base_temp 18

# %%
del X24, y24, lgb_train, lgb_val, y, y_final, y_final_inv, yhat, yhat_final, yhat_final_inv

# %%
def train_lagged_ts(lag_day):
    
    lag = lag_day * 24
    trainX = pd.DataFrame()
    trainy = []
    for ser_id, ser_data in tqdm(train.groupby('series_id')):

        # prepare the data
        X, y, scaler = prepare_training_data(ser_data, lag)
        trainX = pd.concat([trainX,X],axis=0)
        trainy += y
    
    for ser_id, ser_data in tqdm(test.groupby('series_id')):

        if len(ser_data) > lag:
            # prepare the data
            X, y, scaler = prepare_training_data(ser_data, lag)
            trainX = pd.concat([trainX,X],axis=0)
            trainy += y
  
    train_cols = list(trainX.columns)
    train_cols.remove('series_id')
    trainX['target'] = trainy
    
    model = lgb.LGBMRegressor(n_estimators=1000, silent=False, learning_rate=.05)
    #lgb_train = lgb.Dataset(trainX[train_cols], label=trainX['target'], free_raw_data=False)
    #model = lgb.train(param,lgb_train, 200,feval=lgb_smape)
    model = model.fit(trainX[train_cols], trainX['target'],eval_metric = lgb_smape)
    joblib.dump(model,'../lgb{}.pkl'.format(lag_day))
    return True

# %%
for i in range(1,8):
    train_lagged_ts(i)
# Out:
# 100%|██████████| 758/758 [04:14<00:00,  2.97it/s]
# 100%|██████████| 625/625 [02:32<00:00,  4.09it/s]
# 100%|██████████| 758/758 [06:26<00:00,  1.96it/s]
# 100%|██████████| 625/625 [05:10<00:00,  2.01it/s]
# 100%|██████████| 758/758 [09:21<00:00,  1.35it/s]
# 100%|██████████| 625/625 [06:37<00:00,  1.57it/s]
# 100%|██████████| 758/758 [12:23<00:00,  1.02it/s]
# 100%|██████████| 625/625 [08:02<00:00,  1.29it/s]
# 100%|██████████| 758/758 [15:43<00:00,  1.25s/it]
# 100%|██████████| 625/625 [09:14<00:00,  1.13it/s]
# 100%|██████████| 758/758 [20:11<00:00,  1.60s/it]
# 100%|██████████| 625/625 [09:55<00:00,  1.05it/s]
# 100%|██████████| 758/758 [24:43<00:00,  1.96s/it]
# 100%|██████████| 625/625 [11:16<00:00,  1.08s/it]

# %%
'''
### Results

with (0,1) scaling
1. 2 layers LSTM (24,12) =========> .465 => submission1
2. 3 layers LSTM (24,12,6) =======> .53 => submission2
3. 2 layers LSTM (12,6) with lag 12 ======> .408 => submission4
4. 2 layers LSTM (24,24) with lag 24 ======> .61 => submission5
5. 3 layers LSTM (24,24,12) with lag 24 ======> .39 => submission6 (current best)

4. 2 layers LSTM (12,6) with lag 12 bidirectional ======> .43 => submission3
5. 2 layers LSTM (24,12) with lag 24 bidirectional =====> 1.3
6. 2 layers LSTM (6,3) with lag 6 bidirectional =====> .45
7. 2 layers LSTM (12,12) with lag 12 bidirectional =====> .42
8. 2 layers LSTM (12,12) with lag 12 bidirectional with dropout =====>
9. 2 layers LSTM (12,12,6) with lag 12 bidirectional =====>
10. 2 layers LSTM (12,12,6) with lag 12 bidirectional with dropout =====>

with (-1,1) scaling
11. 2 layers LSTM (12,6) with lag 12 ======> .526
11. 2 layers LSTM (12,12) with lag 12 =========> 
12. 3 layers LSTM (24,12,6) =======> 
14. 2 layers LSTM (12,6) with lag 12 bidirectional ======> 
15. 2 layers LSTM (6,3) with lag 6 bidirectional =====>

# %%
models = {}
for i in range(1,8):
    models[i] = joblib.load('../lgb{}.pkl'.format(i))

# %%
def generate_hourly_forecast(num_pred_hours, consumption, model, scaler, lag):
    """ Uses last hour's prediction to generate next for num_pred_hours, 
        initialized by most recent cold start prediction. Inverts scale of 
        predictions before return.
    """
    # allocate prediction frame
    preds_scaled = np.zeros(num_pred_hours)
    
    # initial X is last lag values from the cold start
    X = scaler.transform(consumption.values.reshape(-1, 1))[-lag:]
    
    # forecast
    for i in range(num_pred_hours):
        # predict scaled value for next time step
        yhat = model.predict(X.reshape(1, 1, lag), batch_size=1)[0][0][0]
        preds_scaled[i] = yhat
        
        # update X to be latest data plus prediction
        X = pd.Series(X.ravel()).shift(-1).fillna(yhat).values

    # revert scale back to original range
    hourly_preds = scaler.inverse_transform(preds_scaled.reshape(-1, 1)).ravel()
    return hourly_preds

# %%
pred_window_to_num_preds = {'hourly': 24, 'daily': 7, 'weekly': 2}
pred_window_to_num_pred_hours = {'hourly': 24, 'daily': 7 * 24, 'weekly': 2 * 7 * 24}

# %%
# %%time

num_test_series = my_submission.series_id.nunique()


for ser_id, pred_df in tqdm(my_submission.groupby('series_id'), 
                            total=num_test_series, 
                            desc="Forecasting from Cold Start Data"):
        
    # get info about this series' prediction window
    pred_window = pred_df.prediction_window.unique()[0]
    num_preds = pred_window_to_num_preds[pred_window]
    num_pred_hours = pred_window_to_num_pred_hours[pred_window]
    
    # prepare cold start data
    series_data = test[test.series_id == ser_id].consumption
    cold_X, cold_y, scaler = prepare_training_data(series_data, lag)
    cold_y = cold_y.reshape(cold_y.shape[0],1,1)
    # fine tune our lstm model to this site using cold start data    
    model.fit(cold_X, cold_y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
    
    # make hourly forecasts for duration of pred window
    preds = generate_hourly_forecast(num_pred_hours, series_data, model, scaler, lag)
    
    # reduce by taking sum over each sub window in pred window
    reduced_preds = [pred.sum() for pred in np.split(preds, num_preds)]
    
    # store result in submission DataFrame
    ser_id_mask = my_submission.series_id == ser_id
    my_submission.loc[ser_id_mask, 'consumption'] = reduced_preds

# %%
my_submission.head(10)

# %%
my_submission.to_csv("../data/submmission16.csv",index=False)
