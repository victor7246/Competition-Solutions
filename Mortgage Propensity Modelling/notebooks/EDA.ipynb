# %%
import pandas as pd

pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %%
train = pd.read_csv('../data/CAX_MortgageModeling_Train.csv')

# %%
train.head(3)
# Out:
#      Unique_ID  MORTGAGE NUMBER  PROPERTY VALUE  MORTGAGE PAYMENT    GDS  \
# 0  CAX_Train_1                1          900000              5429  61.98
# 1  CAX_Train_2                2          386000              2179  35.22
# 2  CAX_Train_3                3          531000              2152  30.97
#
#      LTV    TDS  AMORTIZATION  MORTGAGE AMOUNT  RATE MORTGAGE PURPOSE  \
# 0  65.00  71.63           360        1040000.0   4.0        Refinance
# 1  74.29  40.65           360         390000.0   4.5        Refinance
# 2  80.00  35.41           360         424800.0   3.5         Purchase
#
#   PAYMENT FREQUENCY    PROPERTY TYPE  TERM  FSA    AGE RANGE  GENDER  INCOME  \
# 0           Monthly  Single Detached    12  L4C     Under 25    Male  108000
# 1           Monthly  Single Detached    12  L9T  70 and over    Male   78000
# 2           Monthly  Single Detached     6  M1N        35-39  Female   87000
#
#    INCOME TYPE NAICS CODE  CREDIT SCORE  RESULT
# ...

# %%
train.RESULT.value_counts(normalize=True)
# Out:
# FUNDED        0.789251
# NOT FUNDED    0.210749
# Name: RESULT, dtype: float64

# %%
for col in train.columns[2:]:
    if train[col].dtype == object:
        print ("Column {} has {} unique values ".format(col,train[col].nunique()))
# Out:
# Column MORTGAGE PURPOSE has 2 unique values
# Column PAYMENT FREQUENCY has 6 unique values
# Column PROPERTY TYPE has 8 unique values
# Column FSA has 1141 unique values
# Column AGE RANGE has 11 unique values
# Column GENDER has 3 unique values
# Column NAICS CODE has 19 unique values
# Column RESULT has 2 unique values

# %%
import matplotlib.pyplot as plt

# %%
for col in train.columns[2:]:
    if train[col].isnull().any() == True:
        print (col)

# %%
for col in train.columns[2:]:
    print (col)
    if train[col].nunique() > 50:
        try:
            train[col].plot.hist()
        except:
            train[col].value_counts().sort_index(ascending=False).plot.bar()
    else:
        train[col].value_counts().sort_index(ascending=False).plot.bar()
    plt.show()
# Out:
# PROPERTY VALUE
# MORTGAGE PAYMENT
# GDS
# LTV
# TDS
# AMORTIZATION
# MORTGAGE AMOUNT
# RATE
# MORTGAGE PURPOSE
# PAYMENT FREQUENCY
# PROPERTY TYPE
# TERM
# FSA
# AGE RANGE
# GENDER
# INCOME
# INCOME TYPE
# NAICS CODE
# CREDIT SCORE
# RESULT

# %%
train.columns
# Out:
# Index(['Unique_ID', 'MORTGAGE NUMBER', 'PROPERTY VALUE', 'MORTGAGE PAYMENT',
#        'GDS', 'LTV', 'TDS', 'AMORTIZATION', 'MORTGAGE AMOUNT', 'RATE',
#        'MORTGAGE PURPOSE', 'PAYMENT FREQUENCY', 'PROPERTY TYPE', 'TERM', 'FSA',
#        'AGE RANGE', 'GENDER', 'INCOME', 'INCOME TYPE', 'NAICS CODE',
#        'CREDIT SCORE', 'RESULT'],
#       dtype='object')

# %%
train.GDS = train.GDS/100
train['Annual_housing_expense'] = train['INCOME'] * train.GDS
train.LTV = train.LTV/100

# %%
xx = train[col].value_counts()

# %%
xx.plot.
# Out:
# 480        1
# 60         2
# 420       11
# 120       15
# 180       57
# 240      117
# 300     3106
# 360    42333
# Name: AMORTIZATION, dtype: int64
