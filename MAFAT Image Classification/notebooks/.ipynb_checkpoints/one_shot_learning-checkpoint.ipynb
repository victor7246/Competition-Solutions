# %%
import keras
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D
from keras.models import Model, Sequential
from keras.applications.vgg19 import VGG19
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import numpy.random as rng
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.datasets import fetch_olivetti_faces
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %%
input_shape = (128,128,3)
from keras.applications.mobilenet import MobileNet
model = MobileNet(input_shape=input_shape, alpha=1.0, depth_multiplier=1, dropout=1e-3, include_top=False, weights='imagenet', input_tensor=None, pooling=None, classes=1000)
# Out:
# WARNING:tensorflow:From /Users/victor/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...
# 17227776/17225924 [==============================] - 164s 10us/step

# %%
import numpy as np

X_train = np.load('../data/train_tiles_array.npy')
y_train = np.load('../data/labels.npy')

rotation_range = 360

# %%
print (X_train.shape, y_train.shape)
# Out:
# (11617, 128, 128, 3) (11617, 37)

# %%
images = X_train.copy()
del X_train

# %%
input_shape = images[0].shape
print (input_shape)
left_input = Input(input_shape)
right_input = Input(input_shape)
# Out:
# (128, 128, 3)

# %%
last_layer = len(model.layers) - 1
x = model.layers[-1].output
flatten = Flatten()

x = Dense(1024, activation='relu',name='dense_1024')(flatten(model.layers[last_layer].output))

model_final = Model(input=model.layers[0].input,output=x)
# Out:
# /Users/victor/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   import sys

# %%
model_final.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 129, 129, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 64, 64, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 64, 64, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 64, 64, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 64, 64, 32)        128
# ...

# %%
encoded_l = model_final(left_input)
encoded_r = model_final(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1,activation='sigmoid')(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

siamese_net.compile(loss="binary_crossentropy",optimizer='adam')

# %%
siamese_net.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 1024)         20007104    input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1024)         0           model_3[1][0]
#                                                                  model_3[2][0]
# ...

# %%
classes = y_train[:,3:17]

# %%
plt.imshow(images[3,:,:,0])
plt.show()

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, images, classes):
        self.data = images
        self.classes = np.arange(classes.shape[1])
        self.class_image_id = dict(zip(self.classes,[np.argwhere(classes[:,i] == 1).reshape(1,-1)[0] for i in self.classes]))
        self.classes = list(set(self.classes).intersection([i for i in self.class_image_id.keys() if len(self.class_image_id[i]) > 0]))
        
    def get_batch(self,batch_size):
        """Create batch of n pairs, half same class, half different class"""
        X=self.data
        n_examples = len(self.data)
        w, h, _  = input_shape

        #randomly sample several classes to use in the batch
        categories = rng.choice(self.classes,size=(batch_size//2,2))
        categories = np.vstack([categories,np.repeat(rng.choice(self.classes,size=(batch_size-batch_size//2,),replace=True)[:,np.newaxis],2,axis=1)])
        
        #initialize 2 empty arrays for the input image batch
        pairs=[np.zeros((batch_size, h, w,3)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets=np.zeros((batch_size,))
        for i in range(batch_size):
            category1, category2 = categories[i]
            idx_1 = rng.choice(self.class_image_id[category1])
            idx_2 = rng.choice(self.class_image_id[category2])
            pairs[0][i,:,:,:] = self.data[idx_1]
            pairs[1][i,:,:,:] = self.data[idx_2]
            if category1 == category2:
                targets[i] = 1
                
        return pairs, targets
    
    def generate(self, batch_size):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size)
            yield (pairs, targets)

# %%
batch_size = 32
epochs = 20
steps_per_epoch = np.ceil(images.shape[0]/batch_size).astype(int)

# %%
import pandas as pd
val = pd.read_csv('../data/validation_ids.csv')
val_ids = list(val['id'])
train_len = images.shape[0]
train_ids = list(set(range(train_len)) - set(val_ids))
val_count = len(val_ids)

# %%
print (len(train_ids), len(val_ids))
# Out:
# 11540 77

# %%
train_loader = Siamese_Loader(images[train_ids],classes[train_ids])
val_loader = Siamese_Loader(images[val_ids],classes[val_ids])

# %%
checkpoint1 = keras.callbacks.EarlyStopping(monitor='val_loss', verbose=2, patience=5, mode='min')

# %%
siamese_net.fit_generator(train_loader.generate(batch_size),steps_per_epoch=steps_per_epoch,epochs=epochs,validation_data=val_loader.generate(val_count),validation_steps=1, callbacks=[checkpoint1])
# Out:
# Epoch 1/20
# 217/364 [================>.............] - ETA: 8:42 - loss: 7.3835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-29ed2812c9a0> in <module>
# ----> 1 siamese_net.fit_generator(train_loader.generate(batch_size),steps_per_epoch=steps_per_epoch,epochs=epochs,validation_data=val_loader.generate(val_count),validation_steps=1, callbacks=[checkpoint1])
#
# ~/anaconda3/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ...

# %%
val_loader.class_image_id
# Out:
# {0: array([ 1,  7, 13, 18, 19, 24, 33, 34, 40, 41, 44, 46, 50, 64, 66, 72, 75]),
#  1: array([ 0,  2,  3,  4,  5,  8,  9, 10, 11, 12, 15, 16, 17, 21, 23, 26, 27,
#         28, 29, 30, 31, 32, 38, 39, 42, 43, 45, 47, 48, 51, 52, 53, 54, 55,
#         56, 57, 59, 61, 62, 63, 65, 67, 68, 70, 71, 73, 74, 76]),
#  2: array([35]),
#  3: array([37, 49, 58]),
#  4: array([25]),
#  5: array([], dtype=int64),
#  6: array([14, 36, 60, 69]),
#  7: array([], dtype=int64),
#  8: array([], dtype=int64),
#  9: array([], dtype=int64),
#  10: array([], dtype=int64),
#  11: array([ 6, 20, 22]),
#  12: array([], dtype=int64),
#  13: array([], dtype=int64)}

# %%
valX, valY = val_loader.get_batch(val_count)
valpred = siamese_net.predict(valX)
print ("Binary accuracy score is {}".format(accuracy_score(valY,valpred>.5)))
# Out:
# Binary accuracy score is 0.5454545454545454

# %%
plt.imshow(valX[0][row_num,:,:,0])

# %%
plt.figure(figsize=(128,128))
for row_num in range(10):
    sub = plt.subplot(10,2,row_num*2+1)
    sub.axis("off")
    sub.imshow(valX[0][row_num,:,:,0])
    
    sub = plt.subplot(10,2,row_num*2+2,title="Same image {}".format(valpred[row_num][0]>.5))
    sub.axis("off")
    sub.imshow(valX[1][row_num,:,:,0])

# %%
train_features = model_final.predict(images[train_ids])
val_features = model_final.predict(images[val_ids])
print (train_features.shape, val_features.shape)
# Out:
# (11540, 1024) (77, 1024)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(p=1)

# %%
clf.fit(train_features,classes[train_ids])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=1,
#            weights='uniform')

# %%
valpred = np.transpose(np.array(clf.predict_proba(val_features))[:,:,1])
valpred = valpred>.5

# %%
for i in range(valpred.shape[1]):
    print (accuracy_score(classes[val_ids,i],valpred[:,i]))
# Out:
# 0.7012987012987013
# 0.5584415584415584
# 0.987012987012987
# 0.961038961038961
# 0.987012987012987
# 1.0
# 0.948051948051948
# 1.0
# 1.0
# 1.0
# 1.0
# 0.961038961038961
# 1.0
# 1.0

# %%
X_test = np.load('../data/test_tiles_array.npy')
train_features = model_final.predict(images)
test_features = model_final.predict(X_test)

# %%
clf.fit(train_features,classes)
testpred = np.transpose(np.array(clf.predict_proba(test_features))[:,:,1])
np.save('testpred_siamese',testpred)
